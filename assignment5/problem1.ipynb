# %%
import pandas as pd
df = pd.read_json ('universities.json')
print(df)

df2 = pd.read_json ('alumni2.json')
print(df2)

df.to_csv ('universities.csv', index = None)
df2.to_csv ('alumni2.csv', index = None)
# Out:
#                                 universityLabel  yearFounded  \
# 0                               Lund University         1666
# 1                          Karolinska Institute         1810
# 2                          Stockholm University         1878
# 3                      University of Gothenburg         1954
# 4                            Uppsala University         1477
# 5                           University of Borås         1977
# 6                Luleå University of Technology         1971
# 7                Norrland's University Hospital         1907
# 8                             Örebro University         1977
# 9                           Linnaeus University         2010
# 10                          Karlstad University         1977
# 11                        Mid Sweden University         1993
# 12  Swedish University of Agricultural Sciences         1977
# 13                         Linköping University         1975
# ...

# %%
# pip install neo4j-driver

from neo4j import GraphDatabase, basic_auth

driver = GraphDatabase.driver(
    "bolt://52.3.253.48:44816", 
    auth=basic_auth("neo4j", "airship-web-plans"))
session = driver.session()

#https://docs.google.com/spreadsheets/d/1EQpgiGsjJW_h-zngBnAvrz7arTkxNuEHrhdZZdOrbX8/export?format=csv&id=1EQpgiGsjJW_h-zngBnAvrz7arTkxNuEHrhdZZdOrbX8&gid=1588385755

#Universities
#https://docs.google.com/spreadsheets/d/1GbGw_-O77f6l-OQdMuENWeQhPz_DVjRWpGNqRobTq4I/export?format=csv&id=1GbGw_-O77f6l-OQdMuENWeQhPz_DVjRWpGNqRobTq4I&gid=1777971751


cypher_query = '''
LOAD CSV WITH HEADERS FROM 'https://docs.google.com/spreadsheets/d/1GbGw_-O77f6l-OQdMuENWeQhPz_DVjRWpGNqRobTq4I/export?format=csv&id=1GbGw_-O77f6l-OQdMuENWeQhPz_DVjRWpGNqRobTq4I&gid=1777971751' AS line
WITH line
LIMIT 1
RETURN line
'''



results = session.run(cypher_query, parameters={})

print(results)

for record in results:
    print(record)
    
    

    
""""
LOAD CSV WITH HEADERS FROM "'https://docs.google.com/spreadsheets/d/1GbGw_-O77f6l-OQdMuENWeQhPz_DVjRWpGNqRobTq4I/export?format=csv&id=1GbGw_-O77f6l-OQdMuENWeQhPz_DVjRWpGNqRobTq4I&gid=1777971751'" AS csvLine
CREATE (p:Universities {Name: csvLine.universityLabel, year: csvLine.yearFounded})
""""


"""
LOAD CSV WITH HEADERS FROM 'https://docs.google.com/spreadsheets/d/1GbGw_-O77f6l-OQdMuENWeQhPz_DVjRWpGNqRobTq4I/export?format=csv&id=1GbGw_-O77f6l-OQdMuENWeQhPz_DVjRWpGNqRobTq4I&gid=1777971751' AS line
WITH line
LIMIT 1
RETURN line
"""
# Out:
# ...
# <Record line={'universityLabel': 'Lund University', 'countryLabel': 'Sweden', 'location': 'Lund', 'yearFounded': '1666'}>

# %%
cypher_query = '''
MATCH (n)
RETURN id(n) AS id
LIMIT 10
'''

results = session.run(cypher_query,
  parameters={})

for record in results:
    print(record['universityLabel'])
